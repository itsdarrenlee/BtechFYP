# %%
# general 
import pandas as pd 
import numpy as np 
from datetime import datetime

# stats
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# plotting
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt

# settings
plt.style.use('seaborn')
plt.rcParams["figure.figsize"] = (16, 8)
pd.options.plotting.backend = "plotly"

# %%
hrv_file = "04-12-21-HRV-Data-Postprocess-Kubios.csv"
cgm_file = "04-12-21-CGM-Data.csv"

# %%
# parse HRV file
hrv_df = pd.read_csv(hrv_file,
                 index_col="Time")

hrv_df.drop(['Seconds'], axis=1, inplace=True)
hrv_df.head()
# Out:
#             RR
# Time
# 7:31:37  0.855
# 7:31:38  0.855
# 7:31:39  0.862
# 7:31:40  0.890
# 7:31:41  0.950

# %%
cgm_df = pd.read_csv(cgm_file,
                 parse_dates={'date-time': ['Date','Time']},
                 keep_date_col=True,
                 index_col ="date-time")

cgm_df.drop(['Device', 'Serial Number', 'Date'], axis=1, inplace=True)
cgm_df.head()
# Out:
#                      Time  Glucose
# date-time
# 2021-12-04 00:00:00  0:00      5.4
# 2021-12-04 00:15:00  0:15      5.3
# 2021-12-04 00:30:00  0:30      5.1
# 2021-12-04 00:45:00  0:45      4.7
# 2021-12-04 01:00:00  1:00      4.3

# %% [markdown]
# #### Observations
#
# HRV starts from 27097 seconds (7.31am). CGM data starts from 12am. Slicing of time series is necessitated for easier comparison.

# %%
# resample into 1 sec intervals
cgm_df_secs = cgm_df.resample('1s').sum()

# take rows of interest

# %%
cgm_df.head()
# Out:
#                      Time  Glucose
# date-time
# 2021-12-04 00:00:00  0:00      5.4
# 2021-12-04 00:15:00  0:15      5.3
# 2021-12-04 00:30:00  0:30      5.1
# 2021-12-04 00:45:00  0:45      4.7
# 2021-12-04 01:00:00  1:00      4.3

# %%
# resample CGM data
k = cgm_df.Glucose.resample('m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-272591a2ac99> in <module>
#       1 # resample CGM data
# ----> 2 k = cgm_df.Glucose.resample('m')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in get_resampler(obj, kind, **kwds)
#    1309     """
#    1310     tg = TimeGrouper(**kwds)
# -> 1311     return tg._get_resampler(obj, kind=kind)
#    1312
#    1313
#
# ~\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
# ...

# %%
cgm_day_df = cgm_df[cgm_df['Glu']]

# %%
df.plot(
    df['Time'],
    df['RR'],
)
